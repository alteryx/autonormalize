# %%
import os

import pandas as pd
import autonormalize as an
from autonormalize import normalize

# %%
df = pd.read_csv(os.path.join(os.getcwd(), 'autonormalize/examples/example_make_index'))
df = df.drop_duplicates()

# %%
deps = an.find_dependencies(df)
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 22.93it/s]

# %%
print(deps)
# Out:
#  --> A
#  --> B
#  --> C
#  {A,B}  --> D
#  {A,B}  --> E
#  --> F

# %%
depdf = normalize.DepDF(deps, df, ['A','B', 'C', 'F'])
normalize.normalize_dataframe(depdf)

# %%
normalize.make_indexes(depdf)

# %%
dfs = depdf.return_dfs()

# %%
df
# Out:
#         A  B   C      D   E    F
# 0       8  2  19   True  10  304
# 1       7  1  13  False   8   91
# 2      13  1   4  False  14   52
# 3       3  2  14   True   5   84
# 4      16  2   8  False  18  256
# 5      13  2   9   True  15  234
# 6       6  3   8   True   9  144
# 7       3  1  -9  False   4  -27
# 8      12  1  14  False  13  168
# 9      11  1   4  False  12   44
# 10      4  0  -7  False   4    0
# 11     17  0   7  False  17    0
# 12     18  0  -6  False  18    0
# 13      0  0   6  False   0    0
# 14      6  3   9   True   9  162
# 15      4  0  10  False   4    0
# 16      4  2   8   True   6   64
# 17      1  1   9  False   2    9
# 18     14  3  -3   True  17 -126
# 19     14  3   6   True  17  252
# 20      2  2   3   True   4   12
# 21     13  2  10   True  15  260
# 22      2  3  13   True   5   78
# 23     15  1  11  False  16  165
# 24      0  0   5  False   0    0
# 25      7  2  -5   True   9  -70
# 26     24  0   7  False  24    0
# ...

# %%
dfs[0]
# Out:
#        C_A_B_F   C    F  A_B
# 0            0  19  304   34
# 1            1  13   91   29
# 2            2   4   52   53
# 3            3  14   84   14
# 4            4   8  256   66
# 5            5   9  234   54
# 6            6   8  144   27
# 7            7  -9  -27   13
# 8            8  14  168   49
# 9            9   4   44   45
# 10          10  -7    0   16
# 11          11   7    0   68
# 12          12  -6    0   72
# 13          13   6    0    0
# 14          14   9  162   27
# 15          15  10    0   16
# 16          16   8   64   18
# 17          17   9    9    5
# 18          18  -3 -126   59
# 19          19   6  252   59
# 20          20   3   12   10
# 21          21  10  260   54
# 22          22  13   78   11
# 23          23  11  165   61
# 24          24   5    0    0
# 25          25  -5  -70   30
# 26          26   7    0   96
# 27          27  16    0    4
# 28          28 -10    0   16
# 29          29   2    0   80
# ...        ...  ..  ...  ...
# ...

# %%
dfs[1]
# Out:
#      A_B   A  B      D   E
# 0      0   0  0  False   0
# 1      1   0  1  False   1
# 2      2   0  2   True   2
# 3      3   0  3   True   3
# 4      4   1  0  False   1
# 5      5   1  1  False   2
# 6      6   1  2   True   3
# 7      7   1  3   True   4
# 8      8   2  0  False   2
# 9      9   2  1  False   3
# 10    10   2  2   True   4
# 11    11   2  3   True   5
# 12    12   3  0  False   3
# 13    13   3  1  False   4
# 14    14   3  2   True   5
# 15    15   3  3   True   6
# 16    16   4  0  False   4
# 17    17   4  1  False   5
# 18    18   4  2   True   6
# 19    19   4  3   True   7
# 20    20   5  0  False   5
# 21    21   5  1  False   6
# 22    22   5  2   True   7
# 23    23   5  3   True   8
# 24    24   6  0  False   6
# 25    25   6  1  False   7
# 26    26   6  2   True   8
# 27    27   6  3   True   9
# 28    28   7  0  False   7
# 29    29   7  1  False   8
# ..   ...  .. ..    ...  ..
# 74    74  18  2  False  20
# 75    75  18  3  False  21
# ...

# %%
entityset = an.auto_entityset(df, name="example")
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 19.05it/s]

# %%
entityset
# Out:
# Entityset: example
#   Entities:
#     C_A_B_F [Rows: 3224, Columns: 4]
#     A_B [Rows: 104, Columns: 5]
#   Relationships:
#     C_A_B_F.A_B -> A_B.A_B
